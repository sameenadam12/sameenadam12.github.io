# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from windrose import WindroseAxes

# %%
df = pd.read_csv(r'C:\Users\HP\OneDrive\Desktop\Data Mining\T1.csv')

# %%
df.columns
# Out:
# Index(['Date/Time', 'LV ActivePower (kW)', 'Wind Speed (m/s)',
#        'Theoretical_Power_Curve (KWh)', 'Wind Direction (°)'],
#       dtype='object')

# %%
plt.figure(figsize=(5,5))
sns.heatmap(df[['LV ActivePower (kW)', 'Wind Speed (m/s)',
       'Theoretical_Power_Curve (KWh)', 'Wind Direction (°)']].corr(), annot=True)
plt.show()

# %%
df_numeric = df[['LV ActivePower (kW)', 'Wind Speed (m/s)','Theoretical_Power_Curve (KWh)', 'Wind Direction (°)']]
sns.pairplot(df_numeric)
plt.show()

# %%
index = 1
for i in df_numeric.columns:
    plt.subplot(2,2,index)
    sns.boxplot(df[i], color = 'red')
    plt.xlabel(i)
    index += 1
plt.tight_layout()
plt.show()

# %%
ax = WindroseAxes.from_ax()
ax.bar(df['Wind Direction (°)'],df['Wind Speed (m/s)'], normed = True)
ax.set_legend()
plt.legend(loc=[0.9,0.9])
plt.show()
